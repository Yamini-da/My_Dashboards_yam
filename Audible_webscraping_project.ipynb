# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# URL for the webpage to scrape
url = 'https://www.audible.in/cat/Arts-Entertainment/Art-Audiobooks/21881934031?ref_pageloadid=not_applicable&pf_rd_p=e32be111-8c00-4812-b46d-c1d31ffed468&pf_rd_r=0C24CVH3TFGB9NR0WFR7&plink=0ncUe3X3JRT4Q9dJ&pageLoadId=ANfr5CjGzdAH73GH&creativeId=9f32d386-8d17-4de5-8a99-a22191fa0921&ref=a_categories_c0_subCat_1'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find all book titles
span_element = soup.find_all('span', class_="bc-text oneLine bc-spacing-top-s1 bc-size-title2 bc-color-base bc-text-bold bc-text-ellipses")

# Extract the book titles into a list
book_titles = [str(i.text).strip() for i in span_element]

# Find all links to book detail pages
links = soup.find_all('a', href=re.compile(r'^/pd/'))

# Extract the relative URLs (without the base URL)
url2_1 = set()
for link in links:
    if 'href' in link.attrs:
        url2 = link['href']
        url2_1.add(url2)

# Create an empty list to store extracted data
data = []

# Loop over the book titles and URLs
for book_title, url_suffix in zip(book_titles, url2_1):
    urll = 'https://www.audible.in' + url_suffix
    response2 = requests.get(urll)
    soup2 = BeautifulSoup(response2.content, 'html.parser')

    # Extract the rating of the book
    rating = soup2.find('span', class_="bc-text bc-pub-offscreen")
    rating = rating.text.strip() if rating else 'N/A'

    # Extract author, narrator, and length information
    written_by = None
    narrated_by = None
    length = None

    a = soup2.find_all('div', class_='slot centerSlot')
    for div in a:
        li_elements = div.find_all('li', class_='bc-list-item')
        for li in li_elements:
            li_elements2 = li.text.strip()
            text = li_elements2.split('\n')

            # Process each line to find relevant details
            for line in text:
                if 'Written by' in line:
                    written_by = line.replace('Written by:', '').strip()
                if 'Narrated by' in line:
                    narrated_by = line.replace('Narrated by:', '').strip()
                if 'Length:' in line:
                    length = line.replace('Length:', '').strip()

    # Store the extracted data in a dictionary and append it to the list
    data.append({
        'Book Title': book_title,
        'URL': urll,
        'Rating': rating,
        'Written by': written_by,
        'Narrated by': narrated_by,
        'Length': length
    })

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(data)

# %%
df = df.drop_duplicates(subset=['Book Title'])

# %%
df.fillna('N/A',inplace=True)

# %%
df['Rating'] = df['Rating'].str.replace(' out of 5 stars', '', regex=False)

# %%
# Assuming you have a 'Full Text' column in your DataFrame
df['Book Title'] = df.apply(lambda row: row['Full Text'] if '...' in row['Book Title'] else row['Book Title'], axis=1)

# %%
# Function to convert time to total minutes
def convert_to_minutes(time_str):
    hours = 0
    minutes = 0
    # Extract hours and minutes from the time string
    match = re.match(r'(\d+)\s*hrs?\s*and\s*(\d+)\s*mins?', time_str)
    if match:
        hours = int(match.group(1))
        minutes = int(match.group(2))
    # Return total minutes
    return hours * 60 + minutes

# %%
df['Length']= df['Length'].apply(convert_to_minutes)

# %%
df
# Out:
#                                            Book Title  \
# 0              The Steal Like an Artist Audio Trilogy
# 1                                        The Red Book
# 2   Malcolm Gladwell with Robert Krulwich at the 9...
# 3                                  7 Secrets of Shiva
# 4                                       Monuments Men
# 5                                     The Renaissance
# 12                        All the Beauty in the World
# 13                             Playing to the Gallery
# 14                        500 Quotes from Peacemakers
# 15                             The Godfather Notebook
# 16                                  Your Brain on Art
# 17                 So Much Longing in So Little Space
# 18                                         Murakami T
# 19                             Teaching to Transgress
# 20                               The Nolan Variations
# 21  Wabi-Sabi for Artists, Designers, Poets & Phil...
# 22                                   How to Disappear
# 23                                            Culture
# 24                              The Hero's 2 Journeys
# 25                                             Hamlet
# 26                      The World According to Colour
# 27                     The Waste Land and Other Poems
# 28                                               Muse
# 29                                    The Dudes Abide
# 30                           What Are You Looking At?
# 31                             The Laws of Simplicity
# 32                        How to Build a Fashion Icon
# 33              A History of the World in 100 Objects
# 34                                       Wear It Well
# 35                          The Elements of Eloquence
# 36                             Passion Purpose Profit
# 37                 Музыка сфер [Music of the Spheres]
# 38                                 Dipingere il sogno
# 39  Zelda: Detrás de la Leyenda [Zelda: Behind the...
# 40                           El helenismo [Hellenism]
# 41             Pintura románica [Romanesque Painting]
#
#                                                   URL Rating Written by  \
# 0   https://www.audible.in/pd/Cultura-y-Arte-en-Ex...    N/A
# 1   https://www.audible.in/pd/La-republica-romana-...    N/A
# 2   https://www.audible.in/pd/The-World-According-...    N/A
# 3   https://www.audible.in/pd/Escultura-romanica-C...    N/A        N/A
# 4   https://www.audible.in/pd/Culture-Audiobook/B0...      5
# 5   https://www.audible.in/pd/Your-Brain-on-Art-Au...    N/A
# 12  https://www.audible.in/pd/All-the-Beauty-in-th...      5
# 13  https://www.audible.in/pd/Wabi-Sabi-for-Artist...      5
# 14  https://www.audible.in/pd/500-Quotes-from-Peac...    N/A        N/A
# 15               https://www.audible.in/pd/B0DP3K1PT2    N/A        N/A
# 16  https://www.audible.in/pd/Muse-Audiobook/B09YM...    N/A        N/A
# 17  https://www.audible.in/pd/Malcolm-Gladwell-wit...      5
# 18  https://www.audible.in/pd/Wear-It-Well-Audiobo...    N/A
# 19  https://www.audible.in/pd/Vida-y-cultura-del-S...    N/A        N/A
# 20  https://www.audible.in/pd/The-Waste-Land-and-O...      5
# 21  https://www.audible.in/pd/Hamlet-Audiobook/B07...    4.5
# 22  https://www.audible.in/pd/Los-primitivos-flame...    N/A
# 23  https://www.audible.in/pd/7-Secrets-of-Shiva-A...    4.5
# 24  https://www.audible.in/pd/Pintura-del-Siglo-XX...    N/A
# 25  https://www.audible.in/pd/The-Laws-of-Simplici...      4
# 26  https://www.audible.in/pd/El-helenismo-Helleni...    N/A        N/A
# 27  https://www.audible.in/pd/The-Elements-of-Eloq...    4.5
# 28  https://www.audible.in/pd/The-Nolan-Variations...    N/A        N/A
# 29  https://www.audible.in/pd/The-Dudes-Abide-Audi...    N/A
# 30  https://www.audible.in/pd/Playing-to-the-Galle...      5
# 31  https://www.audible.in/pd/Dipingere-il-sogno-A...    N/A
# 32  https://www.audible.in/pd/So-Much-Longing-in-S...      5
# 33  https://www.audible.in/pd/Teaching-to-Transgre...      5
# 34  https://www.audible.in/pd/The-Steal-Like-an-Ar...    4.5
# 35  https://www.audible.in/pd/Primeras-manifestaci...    N/A
# 36  https://www.audible.in/pd/The-Godfather-Notebo...      5
# 37  https://www.audible.in/pd/Murakami-T-Audiobook...    N/A        N/A
# 38  https://www.audible.in/pd/Arte-del-Siglo-XIX-A...    N/A
# 39  https://www.audible.in/pd/El-impresionismo-Imp...    N/A        N/A
# 40  https://www.audible.in/pd/Segunda-mitad-del-Si...    N/A        N/A
# 41  https://www.audible.in/pd/The-Red-Book-Audiobo...      5
#
#    Narrated by  Length
# 0                    0
# 1                    0
# 2                    0
# 3          N/A       0
# 4                    0
# 5                    0
# 12                   0
# 13                   0
# 14         N/A       0
# 15         N/A       0
# 16         N/A       0
# 17                   0
# 18                   0
# 19         N/A       0
# 20                   0
# 21                   0
# 22                   0
# 23                 398
# 24                   0
# 25                   0
# 26         N/A       0
# 27                   0
# 28         N/A       0
# 29                   0
# 30                   0
# 31                   0
# 32                   0
# 33                   0
# 34                 374
# 35                   0
# 36                   0
# 37         N/A       0
# 38                   0
# 39         N/A       0
# 40         N/A       0
# 41                   0
